# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank_df=r'C:\Users\vijay\OneDrive\Desktop\Datafiles of nareshit\bank.csv'
data=pd.read_csv(bank_df,sep=';')
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
filepath=r'C:\Users\vijay\OneDrive\Desktop\Datafiles of nareshit\Visadataset.csv'
df=pd.read_csv(filepath)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df.shape
# Out:
# (25480, 12)

# %%
df.size
# Out:
# 305760

# %%
len(df)
# Out:
# 25480

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# **Day-2**

# %%
df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
data_types=df.dtypes
data_types
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(data_types)
# Out:
# pandas.core.series.Series

# %% [markdown]
# - series type has with out column names
#
# - we can directly apply math operations
#
# - series is a kind of dictnory means key-value pair

# %%
keys=data_types.keys()
keys
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
values=data_types.values
values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
data_types_df=pd.DataFrame(zip(keys,values),columns=['Column_name','Data_type'])
data_types_df.to_csv('data_types_df.csv',index=False)

# %%
pd.read_csv(r'data_types_df.csv')
# Out:
#               Column_name Data_type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# **Task-2**
#
# - I want separate categoriecal
#
# - I want separate  numerical data

# %%
cat_list=[]
num=[]
for i in data_types.items():
    if i==int or float:
        num.append(i)
    else:
        cat_list.append(i)
print(num)
print(cat_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 cat_list=[]
#       2 num=[]
# ----> 3 for i in data_types.items():
#       4     if i==int or float:
#       5         num.append(i)
#
# NameError: name 'data_types' is not defined

# %%
cat_list=[]
for i in data_types.items():
    if i==object:
        cat_list.append(i)
cat_list
# Out:
# []

# %%
dict(data_types_df)
# Out:
# {'Column_name': 0                   case_id
#  1                 continent
#  2     education_of_employee
#  3        has_job_experience
#  4     requires_job_training
#  5           no_of_employees
#  6               yr_of_estab
#  7      region_of_employment
#  8           prevailing_wage
#  9              unit_of_wage
#  10       full_time_position
#  11              case_status
#  Name: Column_name, dtype: object,
#  'Data_type': 0      object
#  1      object
#  2      object
#  3      object
#  4      object
#  5       int64
#  6       int64
#  7      object
#  8     float64
#  9      object
#  10     object
#  11     object
#  Name: Data_type, dtype: object}

# %%
num_list=[]
cat_list=[]
for key,val in zip(keys,values):
    if val=='object':
        cat_list.append(key)
    else:
        num_list.append(key)
print('Categorical data:',cat_list )      
print('Numerical data:',num_list)
# Out:
# Categorical data: ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# Numerical data: ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
dict(data_types)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
cat_list=[ key for key,val in zip(keys,values) if val=='object']
cat_list
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num_list=[key for key,val in zip(keys,values) if val!='object']
num_list
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **Select_dtypes**

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Selection of data**
#
# - take
#
# - loc
#
# - iloc

# %%
df.take(indices=[100,200,300],axis=0)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
cols=[1,8,11]
rows=[100,200,300]
df.take(cols,axis=1).take(rows,axis=0)
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 200      Asia         74441.11   Certified
# 300      Asia        101371.21   Certified

# %%
df.take(indices=[90:93],axis=0)       #not working
# Out:
#   Cell In[229], line 1
#     df.take(indices=[90:93],axis=0)
#                        ^
# SyntaxError: invalid syntax

# %%
l1=range(2,5)
df.take(l1,axis=0)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified

# %%
df.take(2,axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[237], line 1
# ----> 1 df.take(2,axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:893, in BaseBlockManager.take(self, indexer, axis, verify)
#     890 n = self.shape[axis]
# ...

# %%
l1=range(2,5)
l2=[2,3,4,5]
l3=[2:5]
df.take(l1,axis=0)   #working
df.take(l2,axis=0)    #working
df.take(l3,axis=0)   #not working
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified
# ...

# %% [markdown]
# - Draw back at a time either we can select rows and columns

# %%
cols=[1,8,11]
rows=[100,200,300]
df.iloc[rows,cols]
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 200      Asia         74441.11   Certified
# 300      Asia        101371.21   Certified

# %%
df.iloc[[100,200,300],[1,8,11]]
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 200      Asia         74441.11   Certified
# 300      Asia        101371.21   Certified

# %%
df.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
df.iloc[[1,8,11]]
# Out:
#    case_id continent education_of_employee has_job_experience  \
# 1   EZYV02      Asia              Master's                  Y
# 8   EZYV09      Asia            Bachelor's                  N
# 11  EZYV12      Asia           High School                  Y
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 1                      N             2412         2002            Northeast
# 8                      N             4810         2012              Midwest
# 11                     N             4069         2005            Northeast
#
#     prevailing_wage unit_of_wage full_time_position case_status
# 1          83425.65         Year                  Y   Certified
# 8          74362.19         Year                  Y   Certified
# 11         70813.09         Year                  Y      Denied

# %%
df.iloc[100:105,[1,8,11]]
# Out:
#     continent  prevailing_wage case_status
# 100      Asia         28243.79   Certified
# 101      Asia         43421.88   Certified
# 102      Asia         80253.78   Certified
# 103      Asia        115235.95   Certified
# 104      Asia         95200.86   Certified

# %%
df.iloc[[100,200,300],1:4]
# Out:
#     continent education_of_employee has_job_experience
# 100      Asia              Master's                  Y
# 200      Asia             Doctorate                  Y
# 300      Asia              Master's                  Y

# %%
df.iloc[range(1,5),range(1,3)]
# Out:
#   continent education_of_employee
# 1      Asia              Master's
# 2      Asia            Bachelor's
# 3      Asia            Bachelor's
# 4    Africa              Master's

# %%
df.iloc[[100]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
df.iloc[[100,200,300],['continent']]    #not works
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[276], line 1
# ----> 1 df.iloc[[100,200,300],['continent']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[[100,200,300],['case_id','prevailing_wage','case_status']]
# Out:
#      case_id  prevailing_wage case_status
# 100  EZYV101         28243.79   Certified
# 200  EZYV201         74441.11   Certified
# 300  EZYV301        101371.21   Certified

# %%
df.loc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
df.loc['case_id','prevailing_wage','case_status']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[296], line 1
# ----> 1 df.loc['case_id','prevailing_wage','case_status']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1371, in _LocIndexer._getitem_tuple(self, tup)
#    1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
# -> 1371 tup = self._validate_tuple_indexer(tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
#
# ...

# %%
df.loc[100:105,['case_id','prevailing_wage','case_status']]
# Out:
#      case_id  prevailing_wage case_status
# 100  EZYV101         28243.79   Certified
# 101  EZYV102         43421.88   Certified
# 102  EZYV103         80253.78   Certified
# 103  EZYV104        115235.95   Certified
# 104  EZYV105         95200.86   Certified
# 105  EZYV106         41613.52   Certified

# %%
df.loc[[100,200,300],['case_id','prevailing_wage','case_status']]
# Out:
#      case_id  prevailing_wage case_status
# 100  EZYV101         28243.79   Certified
# 200  EZYV201         74441.11   Certified
# 300  EZYV301        101371.21   Certified

# %%
df.loc[[100]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
df.loc[[100,200,300],['continent']]
# Out:
#     continent
# 100      Asia
# 200      Asia
# 300      Asia

# %% [markdown]
# **DaY-3**

# %% [markdown]
# **How to Select the columns**

# %%
#always whenever you open the new note book

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
df[['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
#df['continent','case_status']    #fail beacuse multiple 
df[['continent','case_status']]
# Out:
#       continent case_status
# 0          Asia      Denied
# 1          Asia   Certified
# 2          Asia      Denied
# 3          Asia      Denied
# 4        Africa   Certified
# ...         ...         ...
# 25475      Asia   Certified
# 25476      Asia   Certified
# 25477      Asia   Certified
# 25478      Asia   Certified
# 25479      Asia   Certified
#
# [25480 rows x 2 columns]

# %%
df.loc[:,'continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
df['continent']
df[['continent']]
df.loc[:,'continent']
df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
===========================  Practice :===============================================

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
filepath=r'C:\Users\vijay\OneDrive\Desktop\Datafiles of nareshit\Visadataset.csv'
df=pd.read_csv(filepath)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
