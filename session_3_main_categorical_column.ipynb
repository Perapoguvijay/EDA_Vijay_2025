# %%
import pandas as pd 
import numpy as numpy
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
filepath=r'C:\Users\vijay\OneDrive\Desktop\Datafiles of nareshit\Visadataset.csv'
visa_df=pd.read_csv(filepath)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_column=visa_df.select_dtypes(include='object').columns
cat_column
num_column=visa_df.select_dtypes(exclude='object').columns
num_column
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Unique**

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
len(visa_df['continent'].unique())
# Out:
# 6

# %%
visa_df['continent'].nunique()
# Out:
# 6

# %% [markdown]
# ## frequency table

# %% [markdown]
# - continent columns has some unique continent names ara available
#
# - total data size 25480 observations
#
# - will create a table having continent and number of applications from each continent

# %%
#step-1:total data
visa_df['continent']=='Asia'
#step-2: select pariticular 
visa_df['continent']
#step-3: equating a specific label
con=visa_df['continent']=='Asia'
#step-4: pass the true condition to entire dataframe 
len(visa_df[con])
# Out:
# 16861

# %%
no_of_applications=[]
labels=visa_df['continent'].unique()
for i in labels:
    con=visa_df['continent']==i
    count=len(visa_df[con])
    no_of_applications.append(count)
no_of_applications
# Out:
# [16861, 551, 3292, 3732, 852, 192]

# %%
labels
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
no_of_applications
# Out:
# [16861, 551, 3292, 3732, 852, 192]

# %%
continent_df=pd.DataFrame(zip(labels,no_of_applications),columns=['Continent','No_of_applicable'])
continent_df
continent_df.to_csv('continent_df.csv',index=False)
continent_df
# Out:
#        Continent  No_of_applicable
# 0           Asia             16861
# 1         Africa               551
# 2  North America              3292
# 3         Europe              3732
# 4  South America               852
# 5        Oceania               192

# %%
for col in cat_column:
    print(f'{col}_df.csv')
# Out:
# case_id_df.csv
# continent_df.csv
# education_of_employee_df.csv
# has_job_experience_df.csv
# requires_job_training_df.csv
# region_of_employment_df.csv
# unit_of_wage_df.csv
# full_time_position_df.csv
# case_status_df.csv

# %%
count=[]
for col in cat_column[1:]:
    labels=visa_df[col].unique()
    for label in labels:
        condition=visa_df[col]==label
        count.append(len(visa_df[condition]))
        columns_count_df=pd.DataFrame(zip(labels,count),columns=['column name ','count'])
        columns_count_df.to_csv(f'{col}_df.csv',index=False)

# %% [markdown]
# **Value_count**

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
cat_column
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['case_id'].value_counts()
# Out:
# case_id
# EZYV01       1
# EZYV16995    1
# EZYV16993    1
# EZYV16992    1
# EZYV16991    1
#             ..
# EZYV8492     1
# EZYV8491     1
# EZYV8490     1
# EZYV8489     1
# EZYV25480    1
# Name: count, Length: 25480, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
content_vc=visa_df['continent'].value_counts()
content_vc
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
keys=content_vc.keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values=content_vc.values
values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
continent_df=pd.DataFrame(zip(keys,values),columns=['continent','No of appliactions'])
continent_df.to_csv('continent_df.csv',index=False)

# %%
continent_df
# Out:
#        continent  No of appliactions
# 0           Asia               16861
# 1         Europe                3732
# 2  North America                3292
# 3  South America                 852
# 4         Africa                 551
# 5        Oceania                 192

# %%
for i in cat_column[1:]:
    vc=visa_df[i].value_counts()
    keys=vc.keys()
    values=vc.values
    vc_df=pd.DataFrame(zip(keys,values),columns=[f'{i}','counts'])
    vc_df.to_csv(f'{i}_df.csv')

# %% [markdown]
# - step1: i created a folder i.e freq_tabl
#
# - step2: i get directory path
#
#     - new_directory=python_location+floder
# - step-3:i get the full path
#
#     - new_directory+colname.csv

# %% [markdown]
# **Step-1**

# %%
import os 
folder_name='frequency_tables'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)

# %% [markdown]
# **Step-2:New_Directory**

# %%
cwd=os.getcwd()
nwd=os.path.join(cwd,folder_name)
nwd
# Out:
# 'C:\\Users\\vijay\\Documents\\NareshIT\\Data analytis Numpy\\EDA\\frequency_tables'

# %% [markdown]
# **Step-3:Full paths**

# %%
for i in cat_column[1:]:
    file_name=f'{i}_df.csv'
    path=os.path.join(nwd,file_name)
    print(path)
# Out:
# C:\Users\vijay\Documents\NareshIT\Data analytis Numpy\EDA\frequency_tables\continent_df.csv
# C:\Users\vijay\Documents\NareshIT\Data analytis Numpy\EDA\frequency_tables\education_of_employee_df.csv
# C:\Users\vijay\Documents\NareshIT\Data analytis Numpy\EDA\frequency_tables\has_job_experience_df.csv
# C:\Users\vijay\Documents\NareshIT\Data analytis Numpy\EDA\frequency_tables\requires_job_training_df.csv
# C:\Users\vijay\Documents\NareshIT\Data analytis Numpy\EDA\frequency_tables\region_of_employment_df.csv
# C:\Users\vijay\Documents\NareshIT\Data analytis Numpy\EDA\frequency_tables\unit_of_wage_df.csv
# C:\Users\vijay\Documents\NareshIT\Data analytis Numpy\EDA\frequency_tables\full_time_position_df.csv
# C:\Users\vijay\Documents\NareshIT\Data analytis Numpy\EDA\frequency_tables\case_status_df.csv

# %%
import os 
folder_name='freq_table'
try:
    os.makedirs(folder_name)
except Exception as e:
    print(e)
##################################################################
cwd=os.getcwd()
nwd=os.path.join(cwd,folder_name)
#################################################################
for i in cat_column:
    vc=visa_df[i].value_counts()
    keys=vc.keys()
    values=vc.values
    vc_df=pd.DataFrame(zip(keys,values),columns=['Labels','count'])
    file_name=f'{i}_df.csv'
    path=os.path.join(nwd,file_name)
    vc_df.to_csv(path,index=False)

# %%
path
# Out:
# 'C:\\Users\\vijay\\Documents\\NareshIT\\Data analytis Numpy\\EDA\\frequency_table\\case_status_df.csv'

# %% [markdown]
# **groupby**

# %% [markdown]
# - groupby
#
# - in sql we have a group by option is there
#
# - similarly in python also we have group by
#
# - first it will group the similar labels together
#
# - n that we can perform any math operations

# %%
visa_df.groupby('continent').size()
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# dtype: int64

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %% [markdown]
# - what is the differnce between the groupby and value_counts?
#
# - groupby group the labels and also its return that labels ascending order
#
# - value_counts is the function.that return the labels and counts its not return the any order like asc and desc

# %% [markdown]
# **Bar charts**
#
# - bar charts under the matplotlib
#
# - plt.bar
#
# - bar chart needs class names and class frequency
#
# - class names we can get from value counts
#
# - class frequency we can get value count

# %%
continent=visa_df['continent'].value_counts().keys()
continent
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
count=visa_df['continent'].value_counts().values
count
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
plt.bar(continent,count)
# Out:
# <BarContainer object of 6 artists>

# %%
class_names=visa_df['continent'].value_counts().keys()
class_freq=visa_df['continent'].value_counts().values

colors=['Red','Green','Yellow','Orange','Blue','Cyan']
plt.figure(figsize=(10,5))
plt.bar(class_names,class_freq,color=colors)
plt.xlabel('Class Names')
plt.ylabel('Class Frequency')
plt.title('Continent_Barchart')
plt.savefig('continent_Barchart.jpg')
plt.show()

# %%
visa_df.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
class_names=visa_df['case_status'].value_counts().keys()
class_freq=visa_df['case_status'].value_counts().values

colors=['Red','Green']
plt.figure(figsize=(10,5))
plt.bar(class_names,class_freq,color=colors)
plt.xlabel('Class Names')
plt.ylabel('Class Frequency')
plt.title('case_status_Barchart')
plt.savefig('case_status_Barchart.jpg')
plt.show()

# %%
colors=['Red','Green','Yellow','Orange','Blue','Cyan']
for i in cat_column[1:]:
    class_names=visa_df[i].value_counts().keys()
    class_freq=visa_df[i].value_counts().values

    plt.figure(figsize=(10,5))
    plt.bar(class_names,class_freq,color=colors)
    plt.xlabel('Class Names')
    plt.ylabel('Class Frequency')
    plt.title(f'{i}_Barchart')
    plt.show()

# %% [markdown]
# **Subplots**

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot()
# Out:
# <Axes: >

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
colors=['Red','Green','Blue','Yellow','Orange','Cyan']
plt.figure(figsize=(14,14))
for i in range(1,len(cat_column)):
    class_names=visa_df[cat_column[i]].value_counts().keys()
    class_freq=visa_df[cat_column[i]].value_counts().values
    plt.subplot(3,3,i)
    plt.bar(class_names,class_freq,color=colors)
    plt.xlabel('Class Names')
    plt.ylabel('Class Frequency')
    plt.title(f'{cat_column[i]}_Barchart')

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.pie(values,labels=keys,autopct='%0.2f%%',
       startangle=90,explode=[0.1 for i in range(6)],radius=1)
plt.show()

# %%
visa_df['continent'].value_counts(normalize=True)*100
# Out:
# continent
# Asia             66.173469
# Europe           14.646782
# North America    12.919937
# South America     3.343799
# Africa            2.162480
# Oceania           0.753532
# Name: proportion, dtype: float64
