# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
filepath=r'C:\Users\vijay\OneDrive\Desktop\Datafiles of nareshit\Visadataset.csv'
visa_df=pd.read_csv(filepath)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_column=visa_df.select_dtypes(include='object').columns
cat_column
num_column=visa_df.select_dtypes(exclude='object').columns
num_column
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Histogram**

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data,bins=40)
plt.show()

# %%
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
sns.boxplot(wage_data)
# Out:
# <Axes: ylabel='prevailing_wage'>

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1).hist(wage_data,bins=40)
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.show()

# %%
sns.boxplot(wage_data,orient='h')
plt.show()

# %% [markdown]
# - find the number of  outliers
#
# - Get outliers data and without outliers data

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
up=q3+1.5*iqr
cond1=wage_data<lb
cond2=wage_data>up
main_con=cond1|cond2
outlier_data=visa_df[main_con]
outlier_df=pd.DataFrame(outlier_data)
outlier_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
outlier_df.tail(50)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 22399  EZYV22400           Asia              Master's                  N
# 22548  EZYV22549           Asia            Bachelor's                  Y
# 22647  EZYV22648           Asia            Bachelor's                  N
# 22724  EZYV22725           Asia            Bachelor's                  Y
# 22766  EZYV22767           Asia            Bachelor's                  N
# 22847  EZYV22848           Asia            Bachelor's                  N
# 22851  EZYV22852           Asia              Master's                  Y
# 22866  EZYV22867         Europe           High School                  N
# 23006  EZYV23007           Asia            Bachelor's                  Y
# 23042  EZYV23043           Asia              Master's                  N
# 23214  EZYV23215           Asia            Bachelor's                  N
# 23218  EZYV23219           Asia           High School                  N
# ...

# %% [markdown]
# **non outlier**

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5*iqr
up=q3+1.5*iqr
cond1=wage_data>lb
cond2=wage_data<up
main_con=cond1 & cond2
non_outlier_data=visa_df[main_con]
non_outlier_data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
25053+427
# Out:
# 25480

# %% [markdown]
# - percentage

# %%
(427/25480)*100
# Out:
# 1.6758241758241759

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1).hist(non_outlier_data['prevailing_wage'],bins=40)
plt.subplot(1,2,2).boxplot(non_outlier_data['prevailing_wage'],vert=False)
plt.show()

# %% [markdown]
# **fill the outliers with median**

# %%
#visa_df:25480
#non_outlier_data:25053
#outlier_df:427

# %%
wage_df=visa_df['prevailing_wage'].values
wage_data_outliers=outlier_df['prevailing_wage'].values

# %%
wage_data=visa_df['prevailing_wage'].values
wage_data_outliers=outlier_df['prevailing_wage'].values
med_wage=np.median(wage_data)
list1=[]
for i in wage_data:
    if i in wage_data_outliers:
        list1.append(med_wage)
    else:
        list1.append(i)
visa_df['prevailing_wage_x']=list1

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['prevailing_wage_x'].values
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
x_wage_df=visa_df['prevailing_wage_x']
x_wage_df
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476     70308.2100
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage_x, Length: 25480, dtype: float64

# %%
plt.hist(x_wage_df,bins=10)
plt.show()

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
med_wage
# Out:
# 70308.04999999999
